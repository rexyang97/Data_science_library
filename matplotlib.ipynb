# %%
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties
from matplotlib import font_manager as fm, rcParams

# %%
x=range(2,26,2)
y=[15,13,14,5,17,20,26,26,24,22,18,15]

# %%
plt.figure(figsize=(20,8),dpi=80)

# %%
plt.plot(x,y)
plt.xticks(x)
plt.yticks(range(4,31,2))
plt.show()

# %%
plt.plot(x,y)

# %%
plt.xticks(x)
plt.yticks(range(4,31,2))
plt.show()

# %%
import random
a=[random.randint(20,35)for i in range (120)]
b=[i for i in range(1,121)]

# %%
plt.figure(figsize=(40,8),dpi=80)
plt.plot(b,a)
plt.xticks(b)
plt.yticks(range(20,35))
plt.show()

# %%
a = [1,0,1,1,2,4,3,2,3,4,4,5,6,5,4,3,3,1,1,1]
b=[i for i in range(11,31)]

# %%
plt.figure(figsize=(20,8),dpi=80)
plt.plot(b,a)

# %%
plt.figure(figsize=(15,8),dpi=80)
plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签
plt.rcParams['axes.unicode_minus']=False   #这两行需要手动设置
b_label=["{}岁".format(i) for i in b]
plt.plot(b,a)
plt.xticks(b,b_label)
plt.yticks(range(0,7))
plt.xlabel("岁数")
plt.ylabel("女(男)朋友数量")
plt.title("每年交女(男)朋友的数量走势")
plt.show()

# %%
y3 = [11,17,16,11,12,11,12,6,6,7,8,9,12,15,14,17,18,21,16,17,20,14,15,15,15,19,21,22,22,22,23]
y10 = [26,26,28,19,21,17,16,19,18,20,20,19,22,23,17,20,21,20,22,15,11,15,5,13,17,10,11,13,12,13,6]
x3=[i for i in range(1,32)]
x10=[i for i in range(51,82)]

# %%
x=x3+x10
x_label=["3月{}日".format(i) for i in range(1,32)]
x_label+=["10月{}日".format(i) for i in range(1,32)]
plt.figure(figsize=(24,8),dpi=80)
plt.scatter(x3,y3,label="3月")
plt.scatter(x10,y10,label="10月")
plt.xticks(x[::3],x_label[::3])
plt.legend(loc="upper right")
plt.show()

# %%
a_label = ["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5：最后的骑士","摔跤吧！爸爸","加勒比海盗5：死无对证","金刚：骷髅岛","极限特工：终极回归","生化危机6：终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚狼3：殊死一战","蜘蛛侠：英雄归来","悟空传","银河护卫队2","情圣","新木乃伊",]
a=[i for i in range(len(a_label))]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]

# %%
plt.figure(figsize=(24,10),dpi=80)
plt.bar(a,b)
plt.xticks(a,a_label,rotation=90)
plt.show()

# %%
plt.figure(figsize=(24,10),dpi=80)
plt.barh(a,b,height=0.3)
plt.yticks(a,a_label)
plt.show()

# %%
a_label = ["猩球崛起3：终极之战","敦刻尔克","蜘蛛侠：英雄归来","战狼2"]
a_14=[i for i in range(len(a_label))]
b_16 = [15746,312,4497,319]
b_15 = [12357,156,2045,168]
b_14 = [2358,399,2358,362]
bar_width=0.2
a_15=[i+bar_width for i in a_14]
a_16=[i+bar_width for i in a_15]
plt.figure(figsize=(15,10),dpi=80)
plt.bar(a_14,b_14,width=bar_width,label="14号")
plt.bar(a_15,b_15,width=bar_width,label="15号")
plt.bar(a_16,b_16,width=bar_width,label="16号")
plt.legend(loc="upper right")
plt.xticks(a_15,a_label)
plt.show()

# %%
a=[131,  98, 125, 131, 124, 139, 131, 117, 128, 108, 135, 138, 131, 102, 107, 114, 119, 128, 121, 142, 127, 130, 124, 101, 110, 116, 117, 110, 128, 128, 115,  99, 136, 126, 134,  95, 138, 117, 111,78, 132, 124, 113, 150, 110, 117,  86,  95, 144, 105, 126, 130,126, 130, 126, 116, 123, 106, 112, 138, 123,  86, 101,  99, 136,123, 117, 119, 105, 137, 123, 128, 125, 104, 109, 134, 125, 127,105, 120, 107, 129, 116, 108, 132, 103, 136, 118, 102, 120, 114,105, 115, 132, 145, 119, 121, 112, 139, 125, 138, 109, 132, 134,156, 106, 117, 127, 144, 139, 139, 119, 140,  83, 110, 102,123,107, 143, 115, 136, 118, 139, 123, 112, 118, 125, 109, 119, 133,112, 114, 122, 109, 106, 123, 116, 131, 127, 115, 118, 112, 135,115, 146, 137, 116, 103, 144,  83, 123, 111, 110, 111, 100, 154,136, 100, 118, 119, 133, 134, 106, 129, 126, 110, 111, 109, 141,120, 117, 106, 149, 122, 122, 110, 118, 127, 121, 114, 125, 126,114, 140, 103, 130, 141, 117, 106, 114, 121, 114, 133, 137,  92,121, 112, 146,  97, 137, 105,  98, 117, 112,  81,  97, 139, 113,134, 106, 144, 110, 137, 137, 111, 104, 117, 100, 111, 101, 110,105, 129, 137, 112, 120, 113, 133, 112,  83,  94, 146, 133, 101,131, 116, 111,  84, 137, 115, 122, 106, 144, 109, 123, 116, 111,111, 133, 150]

# %%
d=6
num_bins=(max(a)-min(a))//d
plt.hist(a,num_bins,density=True)
plt.xticks(range(min(a),max(a)+d,d))
plt.show()
